# %% [markdown]
# ### Importing the packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the dataset

# %%
file_location="C:\\Users\\Work Only\\Downloads\\winequality_red.csv"
wine=pd.read_csv(file_location)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Verifying are their any null values in the dataset or not

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Knowing the type of datatype of columns in the dataset

# %%
wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
columns_list=list(wine.columns)
columns_list
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %% [markdown]
# # Performing Expolatory Data Analysis(EDA)

# %% [markdown]
# ### Histograms

# %%
fig,axes=plt.subplots(nrows=3,ncols=4,figsize=(20,15))
plt.subplots_adjust(hspace=1)
for i,ax in zip(columns_list,axes.flat):
    sns.histplot(wine,x=i,ax=ax)
    ax.set_title("Distribution of {}".format(i))

# %% [markdown]
# ### Box Plots

# %%
fig,axes=plt.subplots(nrows=3,ncols=4,figsize=(20,12))
plt.subplots_adjust(hspace=1)
for i,ax in zip(columns_list,axes.flat):
    sns.boxplot(wine,x=i,ax=ax)
    ax.set_title("boxplot of {}".format(i))

# %% [markdown]
# ### Pearson's Corelation Co-efficient

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ### HeatMap

# %%
sns.heatmap(wine.corr())
# Out:
# <Axes: >

# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# ### Importing the necessary packages for linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X=wine.drop(['quality'],axis=1)
y=wine['quality']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size= .30,random_state=26)
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# this gives the co-efficent values of linear regression
# Out:
# array([ 4.75728286e-03, -1.07772930e+00, -1.26643179e-01,  4.02287307e-03,
#        -2.09283698e+00,  3.44637828e-03, -3.53750570e-03, -4.68463264e+00,
#        -4.96451779e-01,  9.23081147e-01,  2.94198473e-01])

# %%
model.intercept_
# this gives the intercept value, nothing but b0(beta-not) value
# Out:
# 9.127278857033344

# %% [markdown]
# ### Every column and their each respective Co-efficient

# %%
c_dataframe=pd.DataFrame(model.coef_, X.columns, columns=['coefficients'])
c_dataframe
# Out:
#                       coefficients
# fixed acidity             0.004757
# volatile acidity         -1.077729
# citric acid              -0.126643
# residual sugar            0.004023
# chlorides                -2.092837
# free sulfur dioxide       0.003446
# total sulfur dioxide     -0.003538
# density                  -4.684633
# pH                       -0.496452
# sulphates                 0.923081
# alcohol                   0.294198

# %% [markdown]
# ### Predicted values of the model

# %%
predictions=model.predict(X_test)
predictions
# Out:
# array([5.69170084, 6.06851582, 5.31021446, 4.68100146, 4.93035037,
#        5.99516144, 6.26023953, 5.54691472, 6.04886629, 5.31070252,
#        5.24931785, 5.83407834, 5.96232199, 5.14468038, 6.5060394 ,
#        6.57982541, 6.40123281, 5.57882507, 5.00262904, 4.80999582,
#        5.75120136, 5.7997274 , 5.1542667 , 4.8337086 , 5.65394143,
#        4.78286928, 5.4512988 , 5.81431649, 5.23785058, 5.44104226,
#        5.64098261, 5.92201554, 6.00908904, 6.08648109, 5.19566449,
#        5.55730662, 6.57952994, 4.87888313, 5.13706454, 5.16496604,
#        5.16168033, 5.82676597, 5.13243407, 5.98638883, 5.14109449,
#        5.56374883, 6.25832268, 6.94366429, 5.11204507, 5.3641419 ,
#        5.53905217, 5.0419729 , 5.51006773, 5.16273662, 5.37113466,
#        5.26273453, 6.56743251, 6.1223396 , 5.47145716, 6.3920549 ,
#        4.79874822, 6.11520219, 5.90250791, 5.746438  , 5.19207555,
#        5.31946147, 6.19799605, 5.64128793, 5.34085476, 5.87151273,
# ...

# %% [markdown]
# # Evaluating the Regression Model

# %% [markdown]
# ### Importing the necessary packages for evaluating the linear regression model

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
MAE = metrics.mean_absolute_error(y_test,predictions)
MAE
# gives the mean absolute error value
# Out:
# 0.48490981060471905

# %%
MSE = metrics.mean_squared_error(y_test,predictions)
MSE
# gives the mean squared error value
# Out:
# 0.38702297313311856

# %%
RMSE = np.sqrt(MSE)
RMSE
# gives the root mean squared error value
# Out:
# 0.6221117047067339

# %%
r2 = metrics.r2_score(y_test,predictions)
r2
# Gives the R-Square value
# Out:
# 0.32280679083606356

# %%
import statsmodels.api as sm

# %%
model1 = sm.OLS(y,X)
# OLS- Ordinary Least Square Method

# %%
model1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                          1.108e+04
# Date:                Thu, 14 Sep 2023   Prob (F-statistic):                        0.00
# Time:                        21:10:59   Log-Likelihood:                         -1569.7
# No. Observations:                1599   AIC:                                      3161.
# Df Residuals:                    1588   BIC:                                      3221.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ...
